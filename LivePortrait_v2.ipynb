# %% [markdown]
# # ✨ LivePortrait Studio V2 - Lái Chuyển Động Cho Ảnh Nhân Vật (Tự Động Lưu Vào Google Drive)
# > **Hướng dẫn 1-Click (Không cần tải lại lần sau):**
# > 1. Bấm **Thời gian chạy (Runtime)** -> **Thay đổi loại phần cứng** -> Chọn **T4 GPU**.
# > 2. Bấm nút ▶️ ở ô lệnh bên dưới -> Bấm **'Kết nối với Google Drive'** khi được hỏi.
# > 3. Lần đầu sẽ lưu trọng số vào Drive, **từ lần thứ 2 trở đi sẽ nạp tức thì từ Drive mà KHÔNG CẦN TẢI LẠI!**

# %%
#@title 🚀 Khởi chạy LivePortrait WebUI 1-Click (Tự Động Caching Google Drive)
# !curl -s -L https://raw.githubusercontent.com/nviethiep55-glitch/my-ai-studio-colab/main/run_liveportrait.py -o /content/run_liveportrait.py
# !python /content/run_liveportrait.py
