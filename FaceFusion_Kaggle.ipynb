# %% [markdown]
# # 🎬 Media Fusion Studio (FaceFusion) On Kaggle - GPU T4 x2
# > **Hướng dẫn 1-Click trên Kaggle:**
# > 1. Ở cột **Settings** bên phải notebook:
# >    - **Accelerator**: Chọn **GPU T4 x2** (hoặc GPU P100)
# >    - **Internet**: Gạt sang **Internet on** (Bắt buộc)
# > 2. Bấm nút ▶️ (Run) ở ô lệnh bên dưới.
# > 3. Sau khi khởi động xong, bấm vào đường link Cloudflare hiển thị ở cuối để vào WebUI!

# %%
#@title 🚀 Khởi chạy FaceFusion 1-Click trên Kaggle
# !curl -s -L "https://raw.githubusercontent.com/nviethiep55-glitch/my-ai-studio-colab/main/run_kaggle_fusion.py?v=$(date +%s)" -o /kaggle/working/run_kaggle_fusion.py
# !python -u /kaggle/working/run_kaggle_fusion.py
